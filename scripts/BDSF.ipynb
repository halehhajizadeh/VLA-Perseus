# %%
import bdsf

# %%
input_image = '../data/19B-053_2019_12_16_T08_12_56.775/products/Images/775-mosaic-fieldAll-StokesI-2.5arc-5000-1e-4-spwALL-pb0.06-cyclenit500-nsigma5-2.image.fits'

# %%
img = bdsf.process_image(input_image, rms_box=(100,20))
# Out:
# --> Opened '../data/19B-053_2019_12_16_T08_12_56.775/products/Images/775-mosaic-fieldAll-StokesI-2.5arc-5000-1e-4-spwALL-pb0.06-cyclenit500-nsigma5-2.image.fits'
# Image size .............................. : (4096, 4096) pixels
# Number of channels ...................... : 1
# Number of Stokes parameters ............. : 1
# Beam shape (major, minor, pos angle) .... : (1.10456e-02, 1.04214e-02, -75.5) degrees
# Frequency of image ...................... : 1499.678 MHz
# Number of blank pixels .................. : 8390116 (50.0%)
# Flux from sum of (non-blank) pixels ..... : 2.334 Jy
# --> Calculating background rms and mean images
# Using user-specified rms_box ............ : (100, 20) pixels
# --> Variation in rms image significant
# --> Using 2D map for background rms
# --> Variation in mean image not significant
# --> Using constant background mean
# Min/max values of background rms map .... : (9.68e-05, 1.14e-03) Jy/beam
# Value of background mean ................ : -4e-05 Jy/beam
# --> Expected 5-sigma-clipped false detection rate < fdr_ratio
# --> Using sigma-clipping ('hard') thresholding
# Minimum number of pixels per island ..... : 90
# Number of islands found ................. : 254
# Fitting islands with Gaussians .......... : [|] 0/254
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# ///////Fitting islands with Gaussians .......... : [/] 1/254Fitting islands with Gaussians .......... : [/] 1/254Fitting islands with Gaussians .......... : [/] 1/254Fitting islands with Gaussians .......... : [/] 1/254Fitting islands with Gaussians .......... : [/] 1/254Fitting islands with Gaussians .......... : [/] 1/254//
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# Fitting islands with Gaussians .......... : [/] 1/254/--Fitting islands with Gaussians .......... : [/] 5/254Fitting islands with Gaussians .......... : [/] 5/254Fitting islands with Gaussians .......... : [/] 5/254|Fitting islands with Gaussians .......... : [-] 6/254Fitting islands with Gaussians .......... : [-] 6/254-Fitting islands with Gaussians .......... : [|] 8/254|||Fitting islands with Gaussians .......... : [-] 10/254|/Fitting islands with Gaussians .......... : [|] 12/254Fitting islands with Gaussians .......... : [|] 12/254-Fitting islands with Gaussians .......... : [|] 12/254Fitting islands with Gaussians .......... : [|] 12/254\\
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# Fitting islands with Gaussians .......... : [/] 13/254|Fitting islands with Gaussians .......... : [-] 14/254Fitting islands with Gaussians .......... : [\] 15/254--Fitting islands with Gaussians .......... : [\] 15/254||
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# Fitting islands with Gaussians .......... : [|] 16/254||Fitting islands with Gaussians .......... : [-] 18/254Fitting islands with Gaussians .......... : [-] 18/254\Fitting islands with Gaussians .......... : [|] 19/254\Fitting islands with Gaussians .......... : [|] 20/254Fitting islands with Gaussians .......... : [|] 20/254/Fitting islands with Gaussians .......... : [|] 20/254/\\Fitting islands with Gaussians .......... : [\] 23/254Fitting islands with Gaussians .......... : [\] 23/254/Fitting islands with Gaussians .......... : [/] 25/254/Fitting islands with Gaussians .......... : [/] 26/254Fitting islands with Gaussians .......... : [\] 27/254Fitting islands with Gaussians .......... : [\] 27/254
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# -Fitting islands with Gaussians .......... : [|] 216/254\Fitting islands with Gaussians .......... : [-] 218/254\Fitting islands with Gaussians .......... : [\] 219/254Fitting islands with Gaussians .......... : [\] 219/254/Fitting islands with Gaussians .......... : [/] 221/254\Fitting islands with Gaussians .......... : [\] 223/254[-1G|Fitting islands with Gaussians .......... : [|] 224/254[-1G/
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# Fitting islands with Gaussians .......... : [/] 225/254[-1G-Fitting islands with Gaussians .......... : [-] 226/254[-2G\Fitting islands with Gaussians .......... : [\] 227/254[-2G||Fitting islands with Gaussians .......... : [|] 228/254[-2GFitting islands with Gaussians .......... : [|] 228/254[-2G
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# --Fitting islands with Gaussians .......... : [-] 230/254[-2GFitting islands with Gaussians .......... : [-] 230/254[-2G|Fitting islands with Gaussians .......... : [|] 232/254[-3G/Fitting islands with Gaussians .......... : [/] 233/254[-3G--Fitting islands with Gaussians .......... : [-] 234/254[-3GFitting islands with Gaussians .......... : [-] 234/254[-3G|Fitting islands with Gaussians .......... : [|] 236/254[-4G/
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# /Fitting islands with Gaussians .......... : [/] 237/254[-4GFitting islands with Gaussians .......... : [/] 237/254[-4G\Fitting islands with Gaussians .......... : [\] 239/254[-4G|Fitting islands with Gaussians .......... : [|] 240/254[-5G/
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# Fitting islands with Gaussians .......... : [/] 241/254[-5G-Fitting islands with Gaussians .......... : [-] 242/254[-5G
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# \Fitting islands with Gaussians .......... : [\] 243/254[-5G|Fitting islands with Gaussians .......... : [|] 244/254[-5G/Fitting islands with Gaussians .......... : [/] 245/254[-6GFitting islands with Gaussians .......... : [] 254/254[-8G
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# stty: stdin isn't a terminal
# Total number of Gaussians fit to image .. : 279
# Total flux density in model ............. : 2.836 Jy
# stty: stdin isn't a terminal
# --> Grouping Gaussians into sources
# Number of sources formed from Gaussians   : 266
# WARNING: All Gaussians were flagged for the following islands:
#     Island #1 (x=828, y=1465): fit with 1 Gaussian with flag = 256
#     Island #93 (x=1892, y=3359): fit with 1 Gaussian with flag = 256
#     Island #210 (x=2909, y=1873): fit with 1 Gaussian with flag = 256
# Please check these islands. If they are valid islands and
# should be fit, try adjusting the flagging options (use
# show_fit with "ch0_flagged=True" to see the flagged Gaussians
# and "help 'flagging_opts'" to see the meaning of the flags)
# or enabling the wavelet module (with "atrous_do=True").
# To include empty islands in output source catalogs, set
# incl_empty=True in the write_catalog task.

# %%
img.write_catalog(format='fits', catalog_type='srl')
# Out:
# --> Wrote FITS file '775-mosaic-fieldAll-StokesI-2.5arc-5000-1e-4-spwALL-pb0.06-cyclenit500-nsigma5-2.image.pybdsf.srl.fits'
# True

# %%
img.export_image(img_type='gaus_resid')
# Out:
# --> Wrote file '775-mosaic-fieldAll-StokesI-2.5arc-5000-1e-4-spwALL-pb0.06-cyclenit500-nsigma5-2.image.pybdsf_gaus_resid.fits'
# True

# %%
img.export_image(img_type='gaus_model', outfile=input_image+'.model')
# Out:
# --> Wrote file '../data/19B-053_2019_12_16_T08_12_56.775/products/Images/775-mosaic-fieldAll-StokesI-2.5arc-5000-1e-4-spwALL-pb0.06-cyclenit500-nsigma5-2.image.fits.model'
# True
